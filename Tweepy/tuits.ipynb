# %%
import credentials
import tweepy 
import pandas as pd

auth = tweepy.OAuthHandler(credentials.API_KEY, credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)

api = tweepy.API(auth)


#new_search = "hugo+app -filter:retweets"
new_search = "hugo+app -filter:retweets"

# %%
print("Twitter user data:")
tweets = tweepy.Cursor(api.search, 
                           q=new_search,
                           lang="es",
                           since='2018-01-01').items(2000)

users_locs = [[ tweet.text,tweet.user.location] for tweet in tweets]

tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['tuit', "location"])

print(tweet_text)
# Out:
# Twitter user data:
#                                                   tuit  \
# 0    No pares, sigue sigue 🎶\n\nSeguimos haciendo s...
# 1                        Como detesto la app de Hugo 😊
# 2    Hoy en @elbanquillosv a las 8 PM por @Vivefmra...
# 3    Seguí en sintonía en #La830 con "El Cantor de ...
# 4    @lilyinthesuns3t Para todo los demás existe má...
# ..                                                 ...
# 238          @chercherichard Se las mando por Hugo app
# 239  Necesito que alguien sea mi Dealer de Stickers...
# 240  Que pereza ir al súper y es que en la app o Hu...
# 241  Ya nos puedes encontrar en @hugo_app  y pagar ...
# 242              @DraColita Ahh si, están en Hugo app.
#
#                       location
# 0
# 1
# 2                  El Salvador
# 3      Río Gallegos, Argentina
# 4
# ..                         ...
# 238   Santa Tecla, El Salvador
# 239  Solidaridad, Quintana Roo
# 240
# 241   Santa Tecla, El Salvador
# 242                         🇩🇴
#
# [243 rows x 2 columns]

# %%
new_search = "hugo+app -filter:retweets"

tweets = tweepy.Cursor(api.search,
                   q=new_search,
                   lang="es",
                   since='2020-01-01').items(1000)

all_tweets = [tweet.text for tweet in tweets]
all_tweets_df = pd.DataFrame(data=all_tweets,
                    columns=['Tweet'])

print("Twitter user data:")
tweets = tweepy.Cursor(api.search, 
                           q=new_search,
                           lang="es",
                           since='2018-01-01').items(1000)

users_locs = [[ tweet.user.screen_name,tweet.user.location] for tweet in tweets]

tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['user', "location"])

all_tweets_df[["user", "location"]] = tweet_text
print(all_tweets_df)
# Out:
# Twitter user data:
#                                                  Tweet             user  \
# 0    No pares, sigue sigue 🎶\n\nSeguimos haciendo s...   TechloverStore
# 1                        Como detesto la app de Hugo 😊   isavalentinagm
# 2    Hoy en @elbanquillosv a las 8 PM por @Vivefmra...     elsalvadorfc
# 3    Seguí en sintonía en #La830 con "El Cantor de ...        LU14AM830
# 4    @lilyinthesuns3t Para todo los demás existe má...  Angelgfernandez
# ..                                                 ...              ...
# 238          @chercherichard Se las mando por Hugo app   LaChainiss0982
# 239  Necesito que alguien sea mi Dealer de Stickers...         Hugo_RQ7
# 240  Que pereza ir al súper y es que en la app o Hu...      sbummergirl
# 241  Ya nos puedes encontrar en @hugo_app  y pagar ...        MinutasLM
# 242              @DraColita Ahh si, están en Hugo app.       DaniaDguez
#
#                       location
# 0
# 1
# 2                  El Salvador
# 3      Río Gallegos, Argentina
# 4
# ..                         ...
# 238   Santa Tecla, El Salvador
# 239  Solidaridad, Quintana Roo
# 240
# 241   Santa Tecla, El Salvador
# 242                         🇩🇴
#
# [243 rows x 3 columns]

# %%
new_search = "hugo+app"
max_tweets = 1000

tweets = tweepy.Cursor(api.search,
                   q=new_search,
                   lang="es",
                  
                   since='2020-01-01').items(max_tweets)
 
# Pulling information from tweets iterable object
# Add or remove tweet information you want in the below list comprehension
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.screen_name, tweet.coordinates, tweet.place,
                tweet.retweet_count, tweet.favorite_count, tweet.lang, tweet.source, tweet.in_reply_to_status_id_str, 
                tweet.in_reply_to_user_id_str, tweet.is_quote_status] for tweet in tweets]
 
# Creation of dataframe from tweets_list
# Add or remove columns as you remove tweet information
tweets_df = pd.DataFrame(tweets_list,columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter @ Name', 'Tweet Coordinates', 'Place Info', 'Retweets', 'Favorites', 'Language', 'Source', 'Replied Tweet Id', 'Replied Tweet User Id Str', 'Quote Status Bool'])

print(tweets_df)
tweets_df.to_csv("tweets_hugo.csv",encoding="utf-8")
# Out:
#                                             Tweet Text      Tweet Datetime  \
# 0    No pares, sigue sigue 🎶\n\nSeguimos haciendo s... 2021-09-17 02:35:18
# 1                        Como detesto la app de Hugo 😊 2021-09-17 01:56:52
# 2    RT @Radioesport914: Hablamos del partido contr... 2021-09-17 00:30:41
# 3    Hoy en @elbanquillosv a las 8 PM por @Vivefmra... 2021-09-17 00:17:32
# 4    Seguí en sintonía en #La830 con "El Cantor de ... 2021-09-16 23:24:39
# ..                                                 ...                 ...
# 406          @chercherichard Se las mando por Hugo app 2021-09-09 00:48:03
# 407  Necesito que alguien sea mi Dealer de Stickers... 2021-09-08 22:53:48
# 408  Que pereza ir al súper y es que en la app o Hu... 2021-09-08 22:31:40
# 409  Ya nos puedes encontrar en @hugo_app  y pagar ... 2021-09-08 21:51:12
# 410              @DraColita Ahh si, están en Hugo app. 2021-09-08 20:34:53
#
#                 Tweet Id  Twitter @ Name Tweet Coordinates Place Info  \
# 0    1438693012914200582  TechloverStore              None       None
# 1    1438683341339901959  isavalentinagm              None       None
# 2    1438661653080465418      CheCapitan              None       None
# 3    1438658343963435008    elsalvadorfc              None       None
# 4    1438645035394867201       LU14AM830              None       None
# ..                   ...             ...               ...        ...
# 406  1435766919852961793  LaChainiss0982              None       None
# 407  1435738169203376128        Hugo_RQ7              None       None
# 408  1435732597846466561     sbummergirl              None       None
# 409  1435722415062061070       MinutasLM              None       None
# 410  1435703206403772418      DaniaDguez              None       None
#
#      Retweets  Favorites Language               Source     Replied Tweet Id  \
# 0           0          4       es  Twitter for Android                 None
# 1           0          0       es   Twitter for iPhone                 None
# 2           3          0       es  Twitter for Android                 None
# 3           0          1       es      Twitter Web App                 None
# 4           0          0       es  Twitter for Android                 None
# ..        ...        ...      ...                  ...                  ...
# 406         0          1       es  Twitter for Android  1435759923208597507
# 407         0          7       es   Twitter for iPhone                 None
# 408         0          0       es   Twitter for iPhone                 None
# 409         1          1       es  Twitter for Android                 None
# 410         0          0       es  Twitter for Android  1435701822694563841
#
#     Replied Tweet User Id Str  Quote Status Bool
# 0                        None              False
# 1                        None              False
# 2                        None              False
# 3                        None              False
# 4                        None              False
# ..                        ...                ...
# 406        712427020987138048              False
# 407                      None              False
# 408                      None              False
# 409                      None              False
# 410                  39820544              False
#
# [411 rows x 13 columns]
